# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle
import utils

zvars = ['f_posx', 'f_posy', 'f_phi', 'f_vx', 'f_vy', 'f_omega', 'f_d', 'f_delta', 'f_theta',
                's_posx', 's_posy', 's_phi', 's_vx', 's_vy', 's_omega', 's_d', 's_delta', 's_theta',
                'f_ddot', 'f_deltadot', 'f_thetadot',
                's_ddot', 's_deltadot', 's_thetadot']

pvars = ['f_xd', 'f_yd', 'f_grad_xd', 'f_grad_yd', 'f_theta_hat', 'f_phi_d',
         's_xd', 's_yd', 's_grad_xd', 's_grad_yd', 's_theta_hat', 's_phi_d',
         'Q1', 'Q2', 'R1', 'R2', 'R3', 'q', 'lr', 'lf', 'm', 'I', 'Df', 'Cf', 'Bf', 'Dr', 'Cr', 'Br', 'Cm1', 'Cm2', 'Cd', 'Croll']

half_track_width = 0.46/2

with open('./log_data/log_data.pickle', 'rb') as f:
    loaded_obj = pickle.load(f)

z_output = loaded_obj['z_output']
all_params_output = loaded_obj['all_parameters_output']
log_info_output = loaded_obj['log_info']

for idx, z in enumerate(z_output):
    p = all_params_output[idx]
    log_info = log_info_output[idx]
    ineq_viol = 0
    for i in range(40):
        
        a = utils.nonlinear_ineq_standard(z[i,:], p[i,:])
        
        if a[0] > 0:
            ineq_viol = 1
            print(f"constraint violated, fast traj, index : {idx}, stage: {i}, value = {a[0]} ")
    
        if a[1] > 0:
            ineq_viol = 1
            time = log_info['solvetime']
            res_ineq = log_info['res_ineq']
            exitflag = log_info['exitflag']
            print(f"constraint violated, safe traj, index : {idx}, stage: {i}, value = {a[1]} ")
    if ineq_viol == 1:
        print(f'index : {idx}, time: {time}, res ineq:{res_ineq}, exitflag : {exitflag}')
# Out:
# constraint violated, safe traj, index : 0, stage: 17, value = 0.00680197
# constraint violated, safe traj, index : 0, stage: 18, value = 0.00965353
# index : 0, time: 0.028719784, res ineq:0.0010235692280995841, exitflag : 0
# constraint violated, safe traj, index : 3, stage: 14, value = 0.00623908
# constraint violated, safe traj, index : 3, stage: 15, value = 0.00594937
# index : 3, time: 0.027970883, res ineq:0.0004655903356792952, exitflag : 0
# constraint violated, safe traj, index : 4, stage: 13, value = 0.0102496
# constraint violated, safe traj, index : 4, stage: 14, value = 0.00688011
# index : 4, time: 0.017013342, res ineq:0.0008464529288344201, exitflag : 0
# constraint violated, safe traj, index : 5, stage: 39, value = 0.0022991
# index : 5, time: 0.030749012, res ineq:0.0002449773557304871, exitflag : 0
# constraint violated, safe traj, index : 7, stage: 34, value = 0.00323012
# constraint violated, safe traj, index : 7, stage: 35, value = 0.0588867
# constraint violated, safe traj, index : 7, stage: 36, value = 0.108444
# constraint violated, safe traj, index : 7, stage: 37, value = 0.162609
# constraint violated, safe traj, index : 7, stage: 38, value = 0.216792
# constraint violated, safe traj, index : 7, stage: 39, value = 0.344332
# index : 7, time: 0.016201413, res ineq:0.0023220863053925456, exitflag : 0
# constraint violated, safe traj, index : 8, stage: 33, value = 0.00846903
# constraint violated, safe traj, index : 8, stage: 34, value = 0.0110222
# constraint violated, safe traj, index : 8, stage: 35, value = 0.00793401
# constraint violated, safe traj, index : 8, stage: 36, value = 0.0246451
# constraint violated, safe traj, index : 8, stage: 37, value = 0.0606231
# constraint violated, safe traj, index : 8, stage: 38, value = 0.109367
# constraint violated, safe traj, index : 8, stage: 39, value = 0.177075
# index : 8, time: 0.036987249, res ineq:4.128961983042301e-05, exitflag : 0
# constraint violated, safe traj, index : 9, stage: 31, value = 0.0313752
# constraint violated, safe traj, index : 9, stage: 32, value = 0.0663937
# constraint violated, safe traj, index : 9, stage: 33, value = 0.0266712
# constraint violated, safe traj, index : 9, stage: 37, value = 0.050093
# constraint violated, safe traj, index : 9, stage: 38, value = 0.138551
# constraint violated, safe traj, index : 9, stage: 39, value = 0.259858
# index : 9, time: 0.033619585, res ineq:0.0026646919713361507, exitflag : 0
# constraint violated, safe traj, index : 10, stage: 31, value = 0.0224849
# constraint violated, safe traj, index : 10, stage: 32, value = 0.0690403
# constraint violated, safe traj, index : 10, stage: 33, value = 0.108777
# constraint violated, safe traj, index : 10, stage: 34, value = 0.0936335
# constraint violated, safe traj, index : 10, stage: 35, value = 0.0281416
# index : 10, time: 0.036745161, res ineq:0.0020896552775424137, exitflag : 0
# constraint violated, safe traj, index : 11, stage: 39, value = 0.0437291
# index : 11, time: 0.027561034, res ineq:0.003680598019754143, exitflag : 0
# constraint violated, safe traj, index : 12, stage: 37, value = 0.00813092
# constraint violated, safe traj, index : 12, stage: 38, value = 0.0423718
# constraint violated, safe traj, index : 12, stage: 39, value = 0.0835938
# index : 12, time: 0.016506232, res ineq:0.0001256439460877275, exitflag : 0
# constraint violated, safe traj, index : 13, stage: 37, value = 0.00217799
# constraint violated, safe traj, index : 13, stage: 38, value = 0.0422744
# constraint violated, safe traj, index : 13, stage: 39, value = 0.118152
# index : 13, time: 0.024014089, res ineq:0.002016777424490492, exitflag : 0
# constraint violated, safe traj, index : 14, stage: 32, value = 0.00344832
# constraint violated, safe traj, index : 14, stage: 37, value = 0.0152872
# constraint violated, safe traj, index : 14, stage: 38, value = 0.0638367
# constraint violated, safe traj, index : 14, stage: 39, value = 0.174855
# index : 14, time: 0.028212014, res ineq:3.248613854839322e-05, exitflag : 0
# constraint violated, safe traj, index : 15, stage: 29, value = 0.00929963
# constraint violated, safe traj, index : 15, stage: 30, value = 0.0114836
# constraint violated, safe traj, index : 15, stage: 37, value = 0.025289
# constraint violated, safe traj, index : 15, stage: 38, value = 0.116138
# constraint violated, safe traj, index : 15, stage: 39, value = 0.261217
# index : 15, time: 0.017008198, res ineq:0.010233940461757922, exitflag : 0
# constraint violated, safe traj, index : 16, stage: 17, value = 2.31153e-06
# constraint violated, safe traj, index : 16, stage: 34, value = 0.0346129
# constraint violated, safe traj, index : 16, stage: 35, value = 0.0909301
# constraint violated, safe traj, index : 16, stage: 36, value = 0.168207
# constraint violated, safe traj, index : 16, stage: 37, value = 0.266279
# constraint violated, safe traj, index : 16, stage: 38, value = 0.384789
# constraint violated, safe traj, index : 16, stage: 39, value = 0.503973
# index : 16, time: 0.031588103, res ineq:0.0005805562579319495, exitflag : 0
# constraint violated, safe traj, index : 17, stage: 27, value = 0.00354942
# constraint violated, safe traj, index : 17, stage: 28, value = 0.00122121
# constraint violated, safe traj, index : 17, stage: 35, value = 0.0602734
# constraint violated, safe traj, index : 17, stage: 36, value = 0.171101
# constraint violated, safe traj, index : 17, stage: 37, value = 0.34364
# constraint violated, safe traj, index : 17, stage: 38, value = 0.562302
# constraint violated, safe traj, index : 17, stage: 39, value = 0.80827
# index : 17, time: 0.030553238, res ineq:0.00012158115799203173, exitflag : 0
# constraint violated, safe traj, index : 18, stage: 31, value = 0.00721193
# constraint violated, safe traj, index : 18, stage: 32, value = 0.0591048
# constraint violated, safe traj, index : 18, stage: 33, value = 0.13092
# constraint violated, safe traj, index : 18, stage: 34, value = 0.222758
# constraint violated, safe traj, index : 18, stage: 35, value = 0.334261
# constraint violated, safe traj, index : 18, stage: 36, value = 0.464911
# constraint violated, safe traj, index : 18, stage: 37, value = 0.614598
# constraint violated, safe traj, index : 18, stage: 38, value = 0.782759
# constraint violated, safe traj, index : 18, stage: 39, value = 0.968833
# index : 18, time: 0.031123303, res ineq:0.0003362289614767931, exitflag : 0
# constraint violated, safe traj, index : 19, stage: 33, value = 0.00396117
# constraint violated, safe traj, index : 19, stage: 34, value = 0.0679735
# constraint violated, safe traj, index : 19, stage: 35, value = 0.178007
# constraint violated, safe traj, index : 19, stage: 36, value = 0.341136
# constraint violated, safe traj, index : 19, stage: 37, value = 0.54624
# constraint violated, safe traj, index : 19, stage: 38, value = 0.788154
# constraint violated, safe traj, index : 19, stage: 39, value = 1.0648
# index : 19, time: 0.027158821, res ineq:0.0040616622100155455, exitflag : 0
# constraint violated, safe traj, index : 20, stage: 30, value = 0.00138561
# constraint violated, safe traj, index : 20, stage: 31, value = 0.0459269
# constraint violated, safe traj, index : 20, stage: 32, value = 0.108673
# constraint violated, safe traj, index : 20, stage: 33, value = 0.188873
# constraint violated, safe traj, index : 20, stage: 34, value = 0.28532
# constraint violated, safe traj, index : 20, stage: 35, value = 0.398222
# constraint violated, safe traj, index : 20, stage: 36, value = 0.525293
# constraint violated, safe traj, index : 20, stage: 37, value = 0.665495
# constraint violated, safe traj, index : 20, stage: 38, value = 0.818204
# constraint violated, safe traj, index : 20, stage: 39, value = 0.980712
# index : 20, time: 0.039146367, res ineq:0.0007473395269378333, exitflag : 0
# constraint violated, safe traj, index : 21, stage: 32, value = 0.0215581
# constraint violated, safe traj, index : 21, stage: 33, value = 0.0974112
# constraint violated, safe traj, index : 21, stage: 34, value = 0.22478
# constraint violated, safe traj, index : 21, stage: 35, value = 0.407016
# constraint violated, safe traj, index : 21, stage: 36, value = 0.632733
# constraint violated, safe traj, index : 21, stage: 37, value = 0.89595
# constraint violated, safe traj, index : 21, stage: 38, value = 1.19175
# constraint violated, safe traj, index : 21, stage: 39, value = 1.51702
# index : 21, time: 0.016726375, res ineq:0.0010643699305340482, exitflag : 0
# constraint violated, safe traj, index : 22, stage: 30, value = 0.0270008
# constraint violated, safe traj, index : 22, stage: 31, value = 0.0636247
# constraint violated, safe traj, index : 22, stage: 32, value = 0.106894
# constraint violated, safe traj, index : 22, stage: 33, value = 0.140313
# constraint violated, safe traj, index : 22, stage: 34, value = 0.176864
# constraint violated, safe traj, index : 22, stage: 35, value = 0.21422
# constraint violated, safe traj, index : 22, stage: 36, value = 0.247749
# constraint violated, safe traj, index : 22, stage: 37, value = 0.277099
# constraint violated, safe traj, index : 22, stage: 38, value = 0.302614
# constraint violated, safe traj, index : 22, stage: 39, value = 0.332561
# index : 22, time: 0.017907108, res ineq:5.857151981253361e-05, exitflag : 0
# constraint violated, safe traj, index : 23, stage: 31, value = 0.0291605
# constraint violated, safe traj, index : 23, stage: 32, value = 0.109367
# constraint violated, safe traj, index : 23, stage: 33, value = 0.241208
# constraint violated, safe traj, index : 23, stage: 34, value = 0.424177
# constraint violated, safe traj, index : 23, stage: 35, value = 0.650992
# constraint violated, safe traj, index : 23, stage: 36, value = 0.901107
# constraint violated, safe traj, index : 23, stage: 37, value = 1.17874
# constraint violated, safe traj, index : 23, stage: 38, value = 1.47264
# constraint violated, safe traj, index : 23, stage: 39, value = 1.77576
# index : 23, time: 0.078378496, res ineq:0.0004898224129674151, exitflag : 0
# constraint violated, safe traj, index : 24, stage: 31, value = 0.0225368
# constraint violated, safe traj, index : 24, stage: 32, value = 0.0407263
# constraint violated, safe traj, index : 24, stage: 33, value = 0.0557465
# constraint violated, safe traj, index : 24, stage: 34, value = 0.0864583
# constraint violated, safe traj, index : 24, stage: 35, value = 0.127332
# constraint violated, safe traj, index : 24, stage: 36, value = 0.187076
# constraint violated, safe traj, index : 24, stage: 37, value = 0.266895
# constraint violated, safe traj, index : 24, stage: 38, value = 0.371985
# constraint violated, safe traj, index : 24, stage: 39, value = 0.48467
# index : 24, time: 0.026298662, res ineq:0.0004858361756726673, exitflag : 0
# constraint violated, safe traj, index : 25, stage: 32, value = 0.0766079
# constraint violated, safe traj, index : 25, stage: 33, value = 0.0249305
# constraint violated, safe traj, index : 25, stage: 39, value = 0.466299
# index : 25, time: 0.027746806, res ineq:7.101944349698075e-05, exitflag : 0
# constraint violated, safe traj, index : 26, stage: 28, value = 0.023498
# constraint violated, safe traj, index : 26, stage: 29, value = 0.0903977
# constraint violated, safe traj, index : 26, stage: 30, value = 0.200443
# constraint violated, safe traj, index : 26, stage: 31, value = 0.349238
# constraint violated, safe traj, index : 26, stage: 32, value = 0.531944
# constraint violated, safe traj, index : 26, stage: 33, value = 0.785175
# constraint violated, safe traj, index : 26, stage: 34, value = 1.05066
# constraint violated, safe traj, index : 26, stage: 35, value = 1.33866
# constraint violated, safe traj, index : 26, stage: 36, value = 1.66448
# constraint violated, safe traj, index : 26, stage: 37, value = 1.99281
# constraint violated, safe traj, index : 26, stage: 38, value = 2.34933
# constraint violated, safe traj, index : 26, stage: 39, value = 2.71841
# index : 26, time: 0.045426541, res ineq:0.0001282369575323684, exitflag : 0
# constraint violated, safe traj, index : 27, stage: 20, value = 0.0186358
# constraint violated, safe traj, index : 27, stage: 21, value = 0.0468753
# constraint violated, safe traj, index : 27, stage: 22, value = 0.0644017
# constraint violated, safe traj, index : 27, stage: 23, value = 0.0698013
# constraint violated, safe traj, index : 27, stage: 24, value = 0.0624701
# constraint violated, safe traj, index : 27, stage: 25, value = 0.0437604
# constraint violated, safe traj, index : 27, stage: 26, value = 0.0404716
# constraint violated, safe traj, index : 27, stage: 27, value = 0.0481965
# constraint violated, safe traj, index : 27, stage: 28, value = 0.0904991
# constraint violated, safe traj, index : 27, stage: 29, value = 0.140715
# constraint violated, safe traj, index : 27, stage: 30, value = 0.203135
# constraint violated, safe traj, index : 27, stage: 31, value = 0.276802
# constraint violated, safe traj, index : 27, stage: 32, value = 0.371225
# constraint violated, safe traj, index : 27, stage: 33, value = 0.48928
# constraint violated, safe traj, index : 27, stage: 34, value = 0.635317
# constraint violated, safe traj, index : 27, stage: 35, value = 0.814767
# constraint violated, safe traj, index : 27, stage: 36, value = 1.00813
# constraint violated, safe traj, index : 27, stage: 37, value = 1.2626
# constraint violated, safe traj, index : 27, stage: 38, value = 1.56429
# constraint violated, safe traj, index : 27, stage: 39, value = 1.33423
# index : 27, time: 0.028949978, res ineq:3.488073444225803e-05, exitflag : 0
# constraint violated, safe traj, index : 28, stage: 37, value = 0.0200963
# constraint violated, safe traj, index : 28, stage: 38, value = 0.0754968
# constraint violated, safe traj, index : 28, stage: 39, value = 0.122846
# index : 28, time: 0.037053051, res ineq:0.00022700867692569912, exitflag : 0
# constraint violated, safe traj, index : 29, stage: 29, value = 0.00405153
# constraint violated, safe traj, index : 29, stage: 30, value = 0.0296818
# constraint violated, safe traj, index : 29, stage: 39, value = 0.14585
# index : 29, time: 0.037099799, res ineq:0.00018829457613546603, exitflag : 0
# constraint violated, safe traj, index : 30, stage: 30, value = 0.00863039
# constraint violated, safe traj, index : 30, stage: 31, value = 0.0299436
# constraint violated, safe traj, index : 30, stage: 39, value = 0.0109331
# index : 30, time: 0.031284963, res ineq:4.581782241051824e-05, exitflag : 0
# constraint violated, safe traj, index : 31, stage: 25, value = 0.00015856
# index : 31, time: 0.032731986, res ineq:0.00031902882429681034, exitflag : 0
# constraint violated, safe traj, index : 35, stage: 35, value = 5.05559e-05
# index : 35, time: 0.018425115, res ineq:0.00011778874562510047, exitflag : 0
# constraint violated, safe traj, index : 40, stage: 35, value = 9.88404e-06
# index : 40, time: 0.018027119, res ineq:5.5070888782770416e-05, exitflag : 0
# constraint violated, safe traj, index : 42, stage: 39, value = 0.00326385
# index : 42, time: 0.027599385, res ineq:3.519096285936607e-05, exitflag : 0
# constraint violated, safe traj, index : 44, stage: 14, value = 0.00012505
# constraint violated, safe traj, index : 44, stage: 15, value = 0.000136591
# constraint violated, safe traj, index : 44, stage: 39, value = 0.0613061
# index : 44, time: 0.026037068, res ineq:0.0010513113851826072, exitflag : 0
# constraint violated, safe traj, index : 45, stage: 14, value = 3.8695e-05
# constraint violated, safe traj, index : 45, stage: 35, value = 0.0268192
# constraint violated, safe traj, index : 45, stage: 36, value = 0.070662
# constraint violated, safe traj, index : 45, stage: 37, value = 0.11767
# constraint violated, safe traj, index : 45, stage: 38, value = 0.160696
# constraint violated, safe traj, index : 45, stage: 39, value = 0.155937
# index : 45, time: 0.027935668, res ineq:0.0002164482411162339, exitflag : 0
# constraint violated, safe traj, index : 46, stage: 27, value = 6.56326e-05
# constraint violated, safe traj, index : 46, stage: 35, value = 0.079232
# constraint violated, safe traj, index : 46, stage: 36, value = 0.261273
# constraint violated, safe traj, index : 46, stage: 37, value = 0.499809
# constraint violated, safe traj, index : 46, stage: 38, value = 0.726045
# constraint violated, safe traj, index : 46, stage: 39, value = 0.989508
# index : 46, time: 0.016901053, res ineq:0.00024144289349904311, exitflag : 0
# constraint violated, safe traj, index : 47, stage: 35, value = 0.014819
# constraint violated, safe traj, index : 47, stage: 36, value = 0.0627158
# constraint violated, safe traj, index : 47, stage: 37, value = 0.137237
# constraint violated, safe traj, index : 47, stage: 38, value = 0.234233
# constraint violated, safe traj, index : 47, stage: 39, value = 0.35444
# index : 47, time: 0.016220738, res ineq:0.0009007510762328898, exitflag : 0
# constraint violated, safe traj, index : 48, stage: 32, value = 0.00358697
# constraint violated, safe traj, index : 48, stage: 33, value = 0.0739621
# constraint violated, safe traj, index : 48, stage: 34, value = 0.143465
# constraint violated, safe traj, index : 48, stage: 35, value = 0.222935
# constraint violated, safe traj, index : 48, stage: 36, value = 0.310626
# constraint violated, safe traj, index : 48, stage: 37, value = 0.504894
# constraint violated, safe traj, index : 48, stage: 38, value = 0.766716
# constraint violated, safe traj, index : 48, stage: 39, value = 1.15456
# index : 48, time: 0.020984375, res ineq:0.00021487140426005728, exitflag : 0
# constraint violated, safe traj, index : 49, stage: 27, value = 0.000349095
# constraint violated, safe traj, index : 49, stage: 28, value = 0.0134547
# constraint violated, safe traj, index : 49, stage: 29, value = 0.0173562
# constraint violated, safe traj, index : 49, stage: 30, value = 0.00707628
# constraint violated, safe traj, index : 49, stage: 31, value = 0.00172698
# constraint violated, safe traj, index : 49, stage: 32, value = 0.00347074
# constraint violated, safe traj, index : 49, stage: 33, value = 0.0202509
# constraint violated, safe traj, index : 49, stage: 34, value = 0.063045
# constraint violated, safe traj, index : 49, stage: 35, value = 0.127025
# constraint violated, safe traj, index : 49, stage: 36, value = 0.217514
# constraint violated, safe traj, index : 49, stage: 37, value = 0.330438
# constraint violated, safe traj, index : 49, stage: 38, value = 0.464475
# constraint violated, safe traj, index : 49, stage: 39, value = 0.606313
# index : 49, time: 0.033364162, res ineq:3.3879061361676704e-05, exitflag : 0
# constraint violated, safe traj, index : 50, stage: 26, value = 0.000695512
# constraint violated, safe traj, index : 50, stage: 34, value = 0.0222797
# constraint violated, safe traj, index : 50, stage: 35, value = 0.0873789
# constraint violated, safe traj, index : 50, stage: 36, value = 0.188691
# constraint violated, safe traj, index : 50, stage: 37, value = 0.327088
# constraint violated, safe traj, index : 50, stage: 38, value = 0.514076
# constraint violated, safe traj, index : 50, stage: 39, value = 0.742199
# index : 50, time: 0.039856842, res ineq:8.399790815118158e-05, exitflag : 0
# constraint violated, safe traj, index : 51, stage: 31, value = 0.0224612
# constraint violated, safe traj, index : 51, stage: 32, value = 0.0801039
# constraint violated, safe traj, index : 51, stage: 33, value = 0.157584
# constraint violated, safe traj, index : 51, stage: 34, value = 0.255374
# constraint violated, safe traj, index : 51, stage: 35, value = 0.373933
# constraint violated, safe traj, index : 51, stage: 36, value = 0.51376
# constraint violated, safe traj, index : 51, stage: 37, value = 0.675319
# constraint violated, safe traj, index : 51, stage: 38, value = 0.858982
# constraint violated, safe traj, index : 51, stage: 39, value = 1.0654
# index : 51, time: 0.020793892, res ineq:0.0023659497373218555, exitflag : 0
# constraint violated, safe traj, index : 52, stage: 31, value = 0.00229109
# constraint violated, safe traj, index : 52, stage: 32, value = 0.0462101
# constraint violated, safe traj, index : 52, stage: 33, value = 0.124253
# constraint violated, safe traj, index : 52, stage: 34, value = 0.239063
# constraint violated, safe traj, index : 52, stage: 35, value = 0.401836
# constraint violated, safe traj, index : 52, stage: 36, value = 0.601596
# constraint violated, safe traj, index : 52, stage: 37, value = 0.830026
# constraint violated, safe traj, index : 52, stage: 38, value = 1.08991
# constraint violated, safe traj, index : 52, stage: 39, value = 1.38127
# index : 52, time: 0.027212131, res ineq:0.00029971070219615356, exitflag : 0
# constraint violated, safe traj, index : 53, stage: 29, value = 0.0236019
# constraint violated, safe traj, index : 53, stage: 30, value = 0.0662034
# constraint violated, safe traj, index : 53, stage: 31, value = 0.116488
# constraint violated, safe traj, index : 53, stage: 32, value = 0.174041
# constraint violated, safe traj, index : 53, stage: 33, value = 0.237563
# constraint violated, safe traj, index : 53, stage: 34, value = 0.309908
# constraint violated, safe traj, index : 53, stage: 35, value = 0.38745
# constraint violated, safe traj, index : 53, stage: 36, value = 0.467941
# constraint violated, safe traj, index : 53, stage: 37, value = 0.551769
# constraint violated, safe traj, index : 53, stage: 38, value = 0.639317
# constraint violated, safe traj, index : 53, stage: 39, value = 0.7484
# index : 53, time: 0.028898215, res ineq:0.00034816452960119426, exitflag : 0
# constraint violated, safe traj, index : 54, stage: 22, value = 0.00221241
# constraint violated, safe traj, index : 54, stage: 30, value = 0.0253571
# constraint violated, safe traj, index : 54, stage: 31, value = 0.100496
# constraint violated, safe traj, index : 54, stage: 32, value = 0.221573
# constraint violated, safe traj, index : 54, stage: 33, value = 0.399709
# constraint violated, safe traj, index : 54, stage: 34, value = 0.60997
# constraint violated, safe traj, index : 54, stage: 35, value = 0.856032
# constraint violated, safe traj, index : 54, stage: 36, value = 1.1263
# constraint violated, safe traj, index : 54, stage: 37, value = 1.41599
# constraint violated, safe traj, index : 54, stage: 38, value = 1.72524
# constraint violated, safe traj, index : 54, stage: 39, value = 2.04029
# index : 54, time: 0.030257593, res ineq:0.0032384256641847732, exitflag : 0
# constraint violated, safe traj, index : 55, stage: 21, value = 0.0107919
# constraint violated, safe traj, index : 55, stage: 22, value = 0.0185452
# constraint violated, safe traj, index : 55, stage: 23, value = 0.0156813
# constraint violated, safe traj, index : 55, stage: 24, value = 0.00845465
# constraint violated, safe traj, index : 55, stage: 29, value = 0.000600198
# constraint violated, safe traj, index : 55, stage: 30, value = 0.0164324
# constraint violated, safe traj, index : 55, stage: 31, value = 0.0410303
# constraint violated, safe traj, index : 55, stage: 32, value = 0.0532843
# constraint violated, safe traj, index : 55, stage: 33, value = 0.068793
# constraint violated, safe traj, index : 55, stage: 34, value = 0.0929753
# constraint violated, safe traj, index : 55, stage: 35, value = 0.127495
# constraint violated, safe traj, index : 55, stage: 36, value = 0.178395
# constraint violated, safe traj, index : 55, stage: 37, value = 0.250453
# constraint violated, safe traj, index : 55, stage: 38, value = 0.34564
# constraint violated, safe traj, index : 55, stage: 39, value = 0.477284
# index : 55, time: 0.027666517, res ineq:0.0001063723134049838, exitflag : 0
# constraint violated, safe traj, index : 56, stage: 30, value = 0.0270169
# constraint violated, safe traj, index : 56, stage: 31, value = 0.164626
# constraint violated, safe traj, index : 56, stage: 32, value = 0.0941014
# constraint violated, safe traj, index : 56, stage: 33, value = 0.0393705
# constraint violated, safe traj, index : 56, stage: 38, value = 0.208905
# constraint violated, safe traj, index : 56, stage: 39, value = 1.23446
# index : 56, time: 0.025598722, res ineq:0.0013523652678754591, exitflag : 0
# constraint violated, safe traj, index : 57, stage: 25, value = 0.0221433
# constraint violated, safe traj, index : 57, stage: 26, value = 0.0705235
# constraint violated, safe traj, index : 57, stage: 27, value = 0.115515
# constraint violated, safe traj, index : 57, stage: 28, value = 0.171071
# constraint violated, safe traj, index : 57, stage: 29, value = 0.273696
# constraint violated, safe traj, index : 57, stage: 30, value = 0.402106
# constraint violated, safe traj, index : 57, stage: 31, value = 0.564803
# constraint violated, safe traj, index : 57, stage: 32, value = 0.757731
# constraint violated, safe traj, index : 57, stage: 33, value = 0.948765
# constraint violated, safe traj, index : 57, stage: 34, value = 1.17106
# constraint violated, safe traj, index : 57, stage: 35, value = 1.40523
# constraint violated, safe traj, index : 57, stage: 36, value = 1.65368
# constraint violated, safe traj, index : 57, stage: 37, value = 1.9119
# constraint violated, safe traj, index : 57, stage: 38, value = 2.20701
# constraint violated, safe traj, index : 57, stage: 39, value = 2.45521
# index : 57, time: 0.026011366, res ineq:0.00012160746733475697, exitflag : 0
# constraint violated, safe traj, index : 58, stage: 28, value = 0.00160463
# constraint violated, safe traj, index : 58, stage: 29, value = 0.0155915
# constraint violated, safe traj, index : 58, stage: 30, value = 0.0279735
# constraint violated, safe traj, index : 58, stage: 31, value = 0.0385349
# constraint violated, safe traj, index : 58, stage: 32, value = 0.0487353
# constraint violated, safe traj, index : 58, stage: 33, value = 0.0646663
# constraint violated, safe traj, index : 58, stage: 34, value = 0.0801955
# constraint violated, safe traj, index : 58, stage: 35, value = 0.0953094
# constraint violated, safe traj, index : 58, stage: 36, value = 0.110816
# constraint violated, safe traj, index : 58, stage: 37, value = 0.129149
# constraint violated, safe traj, index : 58, stage: 38, value = 0.143327
# constraint violated, safe traj, index : 58, stage: 39, value = 0.0739175
# index : 58, time: 0.023640113, res ineq:0.00030709676634851565, exitflag : 0
# constraint violated, safe traj, index : 59, stage: 19, value = 0.00324304
# constraint violated, safe traj, index : 59, stage: 29, value = 0.0184708
# constraint violated, safe traj, index : 59, stage: 30, value = 0.060162
# constraint violated, safe traj, index : 59, stage: 31, value = 0.120337
# constraint violated, safe traj, index : 59, stage: 32, value = 0.193193
# constraint violated, safe traj, index : 59, stage: 33, value = 0.263718
# constraint violated, safe traj, index : 59, stage: 34, value = 0.3304
# constraint violated, safe traj, index : 59, stage: 35, value = 0.411687
# constraint violated, safe traj, index : 59, stage: 36, value = 0.508713
# constraint violated, safe traj, index : 59, stage: 37, value = 0.605324
# constraint violated, safe traj, index : 59, stage: 38, value = 0.699901
# constraint violated, safe traj, index : 59, stage: 39, value = 0.787948
# index : 59, time: 0.027830307, res ineq:0.0014380382988078456, exitflag : 0
# constraint violated, safe traj, index : 60, stage: 18, value = 0.00175739
# constraint violated, safe traj, index : 60, stage: 33, value = 0.0139279
# constraint violated, safe traj, index : 60, stage: 34, value = 0.0473754
# constraint violated, safe traj, index : 60, stage: 35, value = 0.0828309
# constraint violated, safe traj, index : 60, stage: 36, value = 0.118323
# constraint violated, safe traj, index : 60, stage: 37, value = 0.14529
# constraint violated, safe traj, index : 60, stage: 38, value = 0.164053
# constraint violated, safe traj, index : 60, stage: 39, value = 0.077307
# index : 60, time: 0.024098812, res ineq:6.807283562880462e-05, exitflag : 0
# constraint violated, safe traj, index : 61, stage: 28, value = 0.0172837
# constraint violated, safe traj, index : 61, stage: 29, value = 0.0840605
# constraint violated, safe traj, index : 61, stage: 30, value = 0.152316
# constraint violated, safe traj, index : 61, stage: 31, value = 0.08699
# constraint violated, safe traj, index : 61, stage: 32, value = 0.0363481
# constraint violated, safe traj, index : 61, stage: 39, value = 0.473691
# index : 61, time: 0.028086389, res ineq:0.0007256846104831405, exitflag : 0
# constraint violated, safe traj, index : 62, stage: 23, value = 0.0141719
# constraint violated, safe traj, index : 62, stage: 24, value = 0.041359
# constraint violated, safe traj, index : 62, stage: 25, value = 0.0694602
# constraint violated, safe traj, index : 62, stage: 26, value = 0.101427
# constraint violated, safe traj, index : 62, stage: 27, value = 0.1721
# constraint violated, safe traj, index : 62, stage: 28, value = 0.284696
# constraint violated, safe traj, index : 62, stage: 29, value = 0.429396
# constraint violated, safe traj, index : 62, stage: 30, value = 0.588137
# constraint violated, safe traj, index : 62, stage: 31, value = 0.808982
# constraint violated, safe traj, index : 62, stage: 32, value = 1.08824
# constraint violated, safe traj, index : 62, stage: 33, value = 1.33794
# constraint violated, safe traj, index : 62, stage: 34, value = 1.55598
# constraint violated, safe traj, index : 62, stage: 35, value = 1.77688
# constraint violated, safe traj, index : 62, stage: 36, value = 1.99995
# constraint violated, safe traj, index : 62, stage: 37, value = 2.22151
# constraint violated, safe traj, index : 62, stage: 38, value = 2.44778
# constraint violated, safe traj, index : 62, stage: 39, value = 2.65307
# index : 62, time: 0.030931482, res ineq:0.00010386284044193103, exitflag : 0
# constraint violated, safe traj, index : 63, stage: 16, value = 0.0160034
# constraint violated, safe traj, index : 63, stage: 17, value = 0.0499865
# constraint violated, safe traj, index : 63, stage: 18, value = 0.0570292
# constraint violated, safe traj, index : 63, stage: 19, value = 0.0501011
# constraint violated, safe traj, index : 63, stage: 20, value = 0.0481495
# constraint violated, safe traj, index : 63, stage: 21, value = 0.042945
# constraint violated, safe traj, index : 63, stage: 22, value = 0.0233963
# constraint violated, safe traj, index : 63, stage: 23, value = 0.0119725
# constraint violated, safe traj, index : 63, stage: 24, value = 0.00886069
# constraint violated, safe traj, index : 63, stage: 25, value = 0.00728767
# constraint violated, safe traj, index : 63, stage: 26, value = 0.0290657
# constraint violated, safe traj, index : 63, stage: 27, value = 0.0567046
# constraint violated, safe traj, index : 63, stage: 28, value = 0.0936717
# constraint violated, safe traj, index : 63, stage: 29, value = 0.132158
# constraint violated, safe traj, index : 63, stage: 30, value = 0.20385
# constraint violated, safe traj, index : 63, stage: 31, value = 0.297049
# constraint violated, safe traj, index : 63, stage: 32, value = 0.418326
# constraint violated, safe traj, index : 63, stage: 33, value = 0.568574
# constraint violated, safe traj, index : 63, stage: 34, value = 0.756053
# constraint violated, safe traj, index : 63, stage: 35, value = 0.969193
# constraint violated, safe traj, index : 63, stage: 36, value = 1.25065
# constraint violated, safe traj, index : 63, stage: 37, value = 1.58122
# constraint violated, safe traj, index : 63, stage: 38, value = 1.96908
# constraint violated, safe traj, index : 63, stage: 39, value = 1.45876
# index : 63, time: 0.038122894, res ineq:5.298892181463625e-05, exitflag : 0
# constraint violated, safe traj, index : 64, stage: 15, value = 0.00369807
# constraint violated, safe traj, index : 64, stage: 16, value = 0.00571443
# constraint violated, safe traj, index : 64, stage: 36, value = 0.0104381
# constraint violated, safe traj, index : 64, stage: 37, value = 0.0203455
# constraint violated, safe traj, index : 64, stage: 38, value = 0.0111262
# index : 64, time: 0.028828817, res ineq:6.429506648589212e-05, exitflag : 0
# constraint violated, safe traj, index : 65, stage: 14, value = 0.00286503
# constraint violated, safe traj, index : 65, stage: 15, value = 0.00623052
# index : 65, time: 0.02418532, res ineq:4.4892180274820614e-05, exitflag : 0
# constraint violated, safe traj, index : 66, stage: 14, value = 0.00435552
# index : 66, time: 0.019694623, res ineq:5.2689185309658104e-05, exitflag : 0
# constraint violated, safe traj, index : 67, stage: 13, value = 0.00142799
# constraint violated, safe traj, index : 67, stage: 35, value = 5.83092e-05
# index : 67, time: 0.032831284, res ineq:0.00023133305168920176, exitflag : 0
# constraint violated, safe traj, index : 69, stage: 35, value = 0.00112034
# index : 69, time: 0.026126449, res ineq:0.0005415196948446305, exitflag : 0
# constraint violated, safe traj, index : 72, stage: 34, value = 0.00646595
# constraint violated, safe traj, index : 72, stage: 35, value = 0.0193191
# constraint violated, safe traj, index : 72, stage: 36, value = 0.0108009
# index : 72, time: 0.019866647, res ineq:0.0005725780377553377, exitflag : 0
# constraint violated, safe traj, index : 73, stage: 35, value = 0.00235903
# index : 73, time: 0.029471244, res ineq:0.0002284647931250286, exitflag : 0
# constraint violated, safe traj, index : 74, stage: 35, value = 0.00464121
# index : 74, time: 0.026165522, res ineq:9.851794756511947e-05, exitflag : 0
# constraint violated, safe traj, index : 76, stage: 16, value = 4.02151e-05
# constraint violated, safe traj, index : 76, stage: 39, value = 0.00024562
# index : 76, time: 0.027713789, res ineq:0.00027203458006457015, exitflag : 0
# constraint violated, safe traj, index : 77, stage: 38, value = 0.0128975
# constraint violated, safe traj, index : 77, stage: 39, value = 0.01506
# index : 77, time: 0.020471879, res ineq:0.00010185142323874209, exitflag : 0
# constraint violated, safe traj, index : 78, stage: 38, value = 0.0499721
# constraint violated, safe traj, index : 78, stage: 39, value = 0.16166
# index : 78, time: 0.019269226, res ineq:0.0002583173888323735, exitflag : 0
# constraint violated, safe traj, index : 79, stage: 35, value = 0.0084987
# constraint violated, safe traj, index : 79, stage: 36, value = 0.0494876
# constraint violated, safe traj, index : 79, stage: 37, value = 0.107486
# constraint violated, safe traj, index : 79, stage: 38, value = 0.179751
# constraint violated, safe traj, index : 79, stage: 39, value = 0.213685
# index : 79, time: 0.025379608, res ineq:0.00018572263816166775, exitflag : 0
# constraint violated, safe traj, index : 80, stage: 34, value = 0.0080339
# constraint violated, safe traj, index : 80, stage: 35, value = 0.111232
# constraint violated, safe traj, index : 80, stage: 36, value = 0.274421
# constraint violated, safe traj, index : 80, stage: 37, value = 0.456894
# constraint violated, safe traj, index : 80, stage: 38, value = 0.668294
# constraint violated, safe traj, index : 80, stage: 39, value = 0.918358
# index : 80, time: 0.018864088, res ineq:0.001627190908659106, exitflag : 0
# constraint violated, safe traj, index : 81, stage: 31, value = 0.0122234
# constraint violated, safe traj, index : 81, stage: 32, value = 0.0313942
# constraint violated, safe traj, index : 81, stage: 33, value = 0.0540802
# constraint violated, safe traj, index : 81, stage: 34, value = 0.0811247
# constraint violated, safe traj, index : 81, stage: 35, value = 0.116514
# constraint violated, safe traj, index : 81, stage: 36, value = 0.162852
# constraint violated, safe traj, index : 81, stage: 37, value = 0.218158
# constraint violated, safe traj, index : 81, stage: 38, value = 0.288128
# constraint violated, safe traj, index : 81, stage: 39, value = 0.238862
# index : 81, time: 0.025023074, res ineq:0.00039468458686551036, exitflag : 0
# constraint violated, safe traj, index : 83, stage: 27, value = 0.00963832
# constraint violated, safe traj, index : 83, stage: 28, value = 0.0362834
# constraint violated, safe traj, index : 83, stage: 29, value = 0.0250036
# constraint violated, safe traj, index : 83, stage: 30, value = 0.0014993
# constraint violated, safe traj, index : 83, stage: 38, value = 0.0118454
# constraint violated, safe traj, index : 83, stage: 39, value = 0.0289021
# index : 83, time: 0.016603544, res ineq:0.00036766145036682546, exitflag : 0
# constraint violated, safe traj, index : 84, stage: 26, value = 0.0149984
# constraint violated, safe traj, index : 84, stage: 27, value = 0.0182023
# constraint violated, safe traj, index : 84, stage: 28, value = 0.00690952
# constraint violated, safe traj, index : 84, stage: 39, value = 0.0278514
# index : 84, time: 0.024907605, res ineq:0.00010938699969776505, exitflag : 0
# constraint violated, safe traj, index : 85, stage: 24, value = 0.00104764
# constraint violated, safe traj, index : 85, stage: 25, value = 0.0125711
# constraint violated, safe traj, index : 85, stage: 26, value = 0.00764539
# constraint violated, safe traj, index : 85, stage: 34, value = 0.00765076
# constraint violated, safe traj, index : 85, stage: 35, value = 0.0292723
# constraint violated, safe traj, index : 85, stage: 36, value = 0.0691098
# constraint violated, safe traj, index : 85, stage: 37, value = 0.128331
# constraint violated, safe traj, index : 85, stage: 38, value = 0.191487
# constraint violated, safe traj, index : 85, stage: 39, value = 0.230944
# index : 85, time: 0.018026068, res ineq:0.0001109691347912521, exitflag : 0
# constraint violated, safe traj, index : 86, stage: 23, value = 0.00294195
# constraint violated, safe traj, index : 86, stage: 24, value = 0.00850126
# constraint violated, safe traj, index : 86, stage: 25, value = 0.00351215
# constraint violated, safe traj, index : 86, stage: 35, value = 0.0133758
# constraint violated, safe traj, index : 86, stage: 36, value = 0.0641449
# constraint violated, safe traj, index : 86, stage: 37, value = 0.143301
# constraint violated, safe traj, index : 86, stage: 38, value = 0.26563
# constraint violated, safe traj, index : 86, stage: 39, value = 0.453847
# index : 86, time: 0.026858764, res ineq:0.00013265927024120764, exitflag : 0
# constraint violated, safe traj, index : 87, stage: 31, value = 0.0105792
# constraint violated, safe traj, index : 87, stage: 32, value = 0.0489338
# constraint violated, safe traj, index : 87, stage: 33, value = 0.104456
# constraint violated, safe traj, index : 87, stage: 34, value = 0.178323
# constraint violated, safe traj, index : 87, stage: 35, value = 0.27208
# constraint violated, safe traj, index : 87, stage: 36, value = 0.386813
# constraint violated, safe traj, index : 87, stage: 37, value = 0.524311
# constraint violated, safe traj, index : 87, stage: 38, value = 0.684769
# constraint violated, safe traj, index : 87, stage: 39, value = 0.779532
# index : 87, time: 0.016592453, res ineq:2.522010158936827e-05, exitflag : 0
# constraint violated, safe traj, index : 88, stage: 22, value = 0.000310684
# constraint violated, safe traj, index : 88, stage: 32, value = 0.0213583
# constraint violated, safe traj, index : 88, stage: 33, value = 0.0703939
# constraint violated, safe traj, index : 88, stage: 34, value = 0.151368
# constraint violated, safe traj, index : 88, stage: 35, value = 0.283478
# constraint violated, safe traj, index : 88, stage: 36, value = 0.465504
# constraint violated, safe traj, index : 88, stage: 37, value = 0.65965
# constraint violated, safe traj, index : 88, stage: 38, value = 0.87842
# constraint violated, safe traj, index : 88, stage: 39, value = 1.10532
# index : 88, time: 0.016867293, res ineq:0.0007386181137996278, exitflag : 0
# constraint violated, safe traj, index : 89, stage: 30, value = 0.0155556
# constraint violated, safe traj, index : 89, stage: 31, value = 0.0360545
# constraint violated, safe traj, index : 89, stage: 32, value = 0.0570821
# constraint violated, safe traj, index : 89, stage: 33, value = 0.0781214
# constraint violated, safe traj, index : 89, stage: 34, value = 0.0993789
# constraint violated, safe traj, index : 89, stage: 35, value = 0.129677
# constraint violated, safe traj, index : 89, stage: 36, value = 0.162933
# constraint violated, safe traj, index : 89, stage: 37, value = 0.199404
# constraint violated, safe traj, index : 89, stage: 38, value = 0.238131
# constraint violated, safe traj, index : 89, stage: 39, value = 0.279642
# index : 89, time: 0.022452849, res ineq:4.223612829885176e-05, exitflag : 0
# constraint violated, safe traj, index : 90, stage: 31, value = 0.00820229
# constraint violated, safe traj, index : 90, stage: 32, value = 0.038022
# constraint violated, safe traj, index : 90, stage: 33, value = 0.0932469
# constraint violated, safe traj, index : 90, stage: 34, value = 0.185785
# constraint violated, safe traj, index : 90, stage: 35, value = 0.30662
# constraint violated, safe traj, index : 90, stage: 36, value = 0.448234
# constraint violated, safe traj, index : 90, stage: 37, value = 0.596741
# constraint violated, safe traj, index : 90, stage: 38, value = 0.77664
# constraint violated, safe traj, index : 90, stage: 39, value = 0.956019
# index : 90, time: 0.021002583, res ineq:0.00022093028684305044, exitflag : 0
# constraint violated, safe traj, index : 91, stage: 29, value = 0.0139345
# constraint violated, safe traj, index : 91, stage: 30, value = 0.0291556
# constraint violated, safe traj, index : 91, stage: 31, value = 0.0443703
# constraint violated, safe traj, index : 91, stage: 32, value = 0.0578191
# constraint violated, safe traj, index : 91, stage: 33, value = 0.0639551
# constraint violated, safe traj, index : 91, stage: 34, value = 0.0734728
# constraint violated, safe traj, index : 91, stage: 35, value = 0.0838631
# constraint violated, safe traj, index : 91, stage: 36, value = 0.0930476
# constraint violated, safe traj, index : 91, stage: 37, value = 0.100599
# constraint violated, safe traj, index : 91, stage: 38, value = 0.106954
# constraint violated, safe traj, index : 91, stage: 39, value = 0.114021
# index : 91, time: 0.027308122, res ineq:3.661923209960505e-05, exitflag : 0
# constraint violated, safe traj, index : 92, stage: 21, value = 9.59476e-05
# constraint violated, safe traj, index : 92, stage: 31, value = 0.0464798
# constraint violated, safe traj, index : 92, stage: 32, value = 0.146498
# constraint violated, safe traj, index : 92, stage: 33, value = 0.301456
# constraint violated, safe traj, index : 92, stage: 34, value = 0.214076
# constraint violated, safe traj, index : 92, stage: 35, value = 0.141693
# constraint violated, safe traj, index : 92, stage: 36, value = 0.08295
# constraint violated, safe traj, index : 92, stage: 37, value = 0.0364115
# constraint violated, safe traj, index : 92, stage: 38, value = 0.0018583
# index : 92, time: 0.016580534, res ineq:0.0001058722586609051, exitflag : 0
# constraint violated, safe traj, index : 93, stage: 39, value = 0.0222275
# index : 93, time: 0.018776434, res ineq:0.0015139318414263588, exitflag : 0
# constraint violated, safe traj, index : 94, stage: 28, value = 0.00353143
# constraint violated, safe traj, index : 94, stage: 29, value = 0.0163952
# constraint violated, safe traj, index : 94, stage: 30, value = 0.0271063
# constraint violated, safe traj, index : 94, stage: 31, value = 0.0343341
# constraint violated, safe traj, index : 94, stage: 32, value = 0.0427465
# constraint violated, safe traj, index : 94, stage: 33, value = 0.055387
# constraint violated, safe traj, index : 94, stage: 34, value = 0.0682825
# constraint violated, safe traj, index : 94, stage: 35, value = 0.0938441
# constraint violated, safe traj, index : 94, stage: 36, value = 0.11344
# constraint violated, safe traj, index : 94, stage: 37, value = 0.128576
# constraint violated, safe traj, index : 94, stage: 38, value = 0.136112
# constraint violated, safe traj, index : 94, stage: 39, value = 0.142401
# index : 94, time: 0.025932909, res ineq:0.00019175580963634586, exitflag : 0
# constraint violated, safe traj, index : 95, stage: 31, value = 0.000219455
# constraint violated, safe traj, index : 95, stage: 32, value = 0.0179874
# constraint violated, safe traj, index : 95, stage: 33, value = 0.0444112
# constraint violated, safe traj, index : 95, stage: 34, value = 0.0819867
# constraint violated, safe traj, index : 95, stage: 35, value = 0.137842
# constraint violated, safe traj, index : 95, stage: 36, value = 0.204141
# constraint violated, safe traj, index : 95, stage: 37, value = 0.274125
# constraint violated, safe traj, index : 95, stage: 38, value = 0.346104
# constraint violated, safe traj, index : 95, stage: 39, value = 0.424897
# index : 95, time: 0.02148648, res ineq:0.0001311021084488273, exitflag : 0
# constraint violated, safe traj, index : 96, stage: 28, value = 0.00876715
# constraint violated, safe traj, index : 96, stage: 29, value = 0.0228045
# constraint violated, safe traj, index : 96, stage: 30, value = 0.0369336
# constraint violated, safe traj, index : 96, stage: 31, value = 0.0509258
# constraint violated, safe traj, index : 96, stage: 32, value = 0.0647319
# constraint violated, safe traj, index : 96, stage: 33, value = 0.0773521
# constraint violated, safe traj, index : 96, stage: 34, value = 0.0923696
# constraint violated, safe traj, index : 96, stage: 35, value = 0.109565
# constraint violated, safe traj, index : 96, stage: 36, value = 0.127986
# constraint violated, safe traj, index : 96, stage: 37, value = 0.146111
# constraint violated, safe traj, index : 96, stage: 38, value = 0.165862
# constraint violated, safe traj, index : 96, stage: 39, value = 0.173399
# index : 96, time: 0.01974478, res ineq:8.570178778505994e-05, exitflag : 0
# constraint violated, safe traj, index : 97, stage: 28, value = 0.00363166
# constraint violated, safe traj, index : 97, stage: 29, value = 0.0227321
# constraint violated, safe traj, index : 97, stage: 30, value = 0.0535775
# constraint violated, safe traj, index : 97, stage: 31, value = 0.103246
# constraint violated, safe traj, index : 97, stage: 32, value = 0.171716
# constraint violated, safe traj, index : 97, stage: 33, value = 0.266368
# constraint violated, safe traj, index : 97, stage: 34, value = 0.377644
# constraint violated, safe traj, index : 97, stage: 35, value = 0.498852
# constraint violated, safe traj, index : 97, stage: 36, value = 0.620854
# constraint violated, safe traj, index : 97, stage: 37, value = 0.747389
# constraint violated, safe traj, index : 97, stage: 38, value = 0.860958
# constraint violated, safe traj, index : 97, stage: 39, value = 1.00133
# index : 97, time: 0.016641648, res ineq:0.0005641541838969921, exitflag : 0
# constraint violated, safe traj, index : 98, stage: 26, value = 0.00482668
# constraint violated, safe traj, index : 98, stage: 27, value = 0.00742368
# constraint violated, safe traj, index : 98, stage: 28, value = 0.00685319
# constraint violated, safe traj, index : 98, stage: 29, value = 0.00249767
# constraint violated, safe traj, index : 98, stage: 36, value = 0.0056639
# constraint violated, safe traj, index : 98, stage: 37, value = 0.0209377
# constraint violated, safe traj, index : 98, stage: 38, value = 0.0305742
# index : 98, time: 0.020404337, res ineq:4.768203231889654e-05, exitflag : 0
# constraint violated, safe traj, index : 99, stage: 18, value = 0.00302904
# constraint violated, safe traj, index : 99, stage: 29, value = 0.0417146
# constraint violated, safe traj, index : 99, stage: 30, value = 0.110987
# constraint violated, safe traj, index : 99, stage: 31, value = 0.148694
# constraint violated, safe traj, index : 99, stage: 32, value = 0.0849988
# constraint violated, safe traj, index : 99, stage: 33, value = 0.0348963
# constraint violated, safe traj, index : 99, stage: 39, value = 0.0010251
# index : 99, time: 0.056800723, res ineq:0.0006185258422765835, exitflag : 0
# constraint violated, safe traj, index : 100, stage: 35, value = 0.00643967
# constraint violated, safe traj, index : 100, stage: 36, value = 0.0991601
# constraint violated, safe traj, index : 100, stage: 37, value = 0.228737
# constraint violated, safe traj, index : 100, stage: 38, value = 0.2663
# constraint violated, safe traj, index : 100, stage: 39, value = 0.297561
# index : 100, time: 0.028307743, res ineq:0.0023017022227616556, exitflag : 0
# constraint violated, safe traj, index : 101, stage: 25, value = 0.000134549
# ...
# constraint violated, safe traj, index : 774, stage: 31, value = 0.00723136
# constraint violated, safe traj, index : 774, stage: 32, value = 0.0514493
# constraint violated, safe traj, index : 774, stage: 33, value = 0.127437
# constraint violated, safe traj, index : 774, stage: 34, value = 0.24305
# constraint violated, safe traj, index : 774, stage: 35, value = 0.403794
# constraint violated, safe traj, index : 774, stage: 36, value = 0.592888
# constraint violated, safe traj, index : 774, stage: 37, value = 0.81259
# constraint violated, safe traj, index : 774, stage: 38, value = 1.05931
# constraint violated, safe traj, index : 774, stage: 39, value = 1.33059
# index : 774, time: 0.016433786, res ineq:0.0006791502997631899, exitflag : 0
# constraint violated, fast traj, index : 775, stage: 1, value = 0.0324891
# constraint violated, safe traj, index : 775, stage: 1, value = 0.158284
# constraint violated, safe traj, index : 775, stage: 29, value = 0.0076639
# constraint violated, safe traj, index : 775, stage: 30, value = 0.0450122
# constraint violated, safe traj, index : 775, stage: 31, value = 0.0908076
# constraint violated, safe traj, index : 775, stage: 32, value = 0.146284
# constraint violated, safe traj, index : 775, stage: 33, value = 0.209152
# constraint violated, safe traj, index : 775, stage: 34, value = 0.283568
# constraint violated, safe traj, index : 775, stage: 35, value = 0.362772
# constraint violated, safe traj, index : 775, stage: 36, value = 0.445469
# constraint violated, safe traj, index : 775, stage: 37, value = 0.530275
# constraint violated, safe traj, index : 775, stage: 38, value = 0.616944
# constraint violated, safe traj, index : 775, stage: 39, value = 0.709819
# index : 775, time: 0.015223939, res ineq:2.6030787779698916e-05, exitflag : 0
# constraint violated, fast traj, index : 776, stage: 0, value = 8.46906e-08
# constraint violated, fast traj, index : 776, stage: 1, value = 0.024581
# constraint violated, safe traj, index : 776, stage: 1, value = 0.155335
# constraint violated, safe traj, index : 776, stage: 30, value = 0.0243176
# constraint violated, safe traj, index : 776, stage: 31, value = 0.101765
# constraint violated, safe traj, index : 776, stage: 32, value = 0.231188
# constraint violated, safe traj, index : 776, stage: 33, value = 0.421071
# constraint violated, safe traj, index : 776, stage: 34, value = 0.64239
# constraint violated, safe traj, index : 776, stage: 35, value = 0.877914
# constraint violated, safe traj, index : 776, stage: 36, value = 1.13808
# constraint violated, safe traj, index : 776, stage: 37, value = 1.41306
# constraint violated, safe traj, index : 776, stage: 38, value = 1.68988
# constraint violated, safe traj, index : 776, stage: 39, value = 1.97203
# index : 776, time: 0.01627954, res ineq:3.996437756920157e-05, exitflag : 0
# constraint violated, fast traj, index : 777, stage: 0, value = 8.77099e-08
# constraint violated, safe traj, index : 777, stage: 0, value = 3.30047e-09
# constraint violated, fast traj, index : 777, stage: 1, value = 0.0173877
# constraint violated, safe traj, index : 777, stage: 1, value = 0.144645
# constraint violated, safe traj, index : 777, stage: 22, value = 0.00914818
# constraint violated, safe traj, index : 777, stage: 23, value = 0.0197684
# constraint violated, safe traj, index : 777, stage: 24, value = 0.0253161
# constraint violated, safe traj, index : 777, stage: 25, value = 0.0221671
# constraint violated, safe traj, index : 777, stage: 26, value = 0.0146057
# constraint violated, safe traj, index : 777, stage: 27, value = 0.00566449
# constraint violated, safe traj, index : 777, stage: 29, value = 0.00608021
# constraint violated, safe traj, index : 777, stage: 30, value = 0.0303529
# constraint violated, safe traj, index : 777, stage: 31, value = 0.0634788
# constraint violated, safe traj, index : 777, stage: 32, value = 0.0948721
# constraint violated, safe traj, index : 777, stage: 33, value = 0.136017
# constraint violated, safe traj, index : 777, stage: 34, value = 0.188804
# constraint violated, safe traj, index : 777, stage: 35, value = 0.264181
# constraint violated, safe traj, index : 777, stage: 36, value = 0.359685
# constraint violated, safe traj, index : 777, stage: 37, value = 0.48431
# constraint violated, safe traj, index : 777, stage: 38, value = 0.641979
# constraint violated, safe traj, index : 777, stage: 39, value = 0.830874
# index : 777, time: 0.015335636, res ineq:3.4617438892786586e-05, exitflag : 0
# constraint violated, fast traj, index : 778, stage: 1, value = 0.0111556
# constraint violated, safe traj, index : 778, stage: 1, value = 0.145628
# constraint violated, safe traj, index : 778, stage: 31, value = 0.0320644
# constraint violated, safe traj, index : 778, stage: 38, value = 0.0637271
# constraint violated, safe traj, index : 778, stage: 39, value = 0.38798
# index : 778, time: 0.032595461, res ineq:0.00017605569965367662, exitflag : 0
# constraint violated, safe traj, index : 779, stage: 0, value = 2.31922e-11
# constraint violated, fast traj, index : 779, stage: 1, value = 0.00625392
# constraint violated, safe traj, index : 779, stage: 1, value = 0.146699
# constraint violated, safe traj, index : 779, stage: 36, value = 0.00417162
# constraint violated, safe traj, index : 779, stage: 37, value = 0.0214521
# constraint violated, safe traj, index : 779, stage: 38, value = 0.0400947
# constraint violated, safe traj, index : 779, stage: 39, value = 0.0586928
# index : 779, time: 0.034355168, res ineq:2.846964072243663e-05, exitflag : 0
# constraint violated, safe traj, index : 780, stage: 0, value = 4.67134e-08
# constraint violated, fast traj, index : 780, stage: 1, value = 0.00247079
# constraint violated, safe traj, index : 780, stage: 1, value = 0.148272
# constraint violated, safe traj, index : 780, stage: 29, value = 0.0389699
# constraint violated, safe traj, index : 780, stage: 30, value = 0.0956034
# constraint violated, safe traj, index : 780, stage: 31, value = 0.170721
# constraint violated, safe traj, index : 780, stage: 32, value = 0.264898
# constraint violated, safe traj, index : 780, stage: 33, value = 0.378294
# constraint violated, safe traj, index : 780, stage: 34, value = 0.444552
# constraint violated, safe traj, index : 780, stage: 35, value = 0.488799
# constraint violated, safe traj, index : 780, stage: 36, value = 0.523236
# constraint violated, safe traj, index : 780, stage: 37, value = 0.534358
# constraint violated, safe traj, index : 780, stage: 38, value = 0.494608
# constraint violated, safe traj, index : 780, stage: 39, value = 0.29801
# index : 780, time: 0.01596847, res ineq:0.00010462142940154129, exitflag : 0
# constraint violated, fast traj, index : 781, stage: 1, value = 0.00111404
# constraint violated, safe traj, index : 781, stage: 1, value = 0.147472
# constraint violated, safe traj, index : 781, stage: 22, value = 0.00990005
# constraint violated, safe traj, index : 781, stage: 23, value = 0.0287924
# constraint violated, safe traj, index : 781, stage: 24, value = 0.0547693
# constraint violated, safe traj, index : 781, stage: 25, value = 0.086055
# constraint violated, safe traj, index : 781, stage: 26, value = 0.120681
# constraint violated, safe traj, index : 781, stage: 27, value = 0.151952
# constraint violated, safe traj, index : 781, stage: 28, value = 0.18643
# constraint violated, safe traj, index : 781, stage: 29, value = 0.254765
# constraint violated, safe traj, index : 781, stage: 30, value = 0.360895
# constraint violated, safe traj, index : 781, stage: 31, value = 0.491489
# constraint violated, safe traj, index : 781, stage: 32, value = 0.643691
# constraint violated, safe traj, index : 781, stage: 33, value = 0.820765
# constraint violated, safe traj, index : 781, stage: 34, value = 1.01548
# constraint violated, safe traj, index : 781, stage: 35, value = 1.2255
# constraint violated, safe traj, index : 781, stage: 36, value = 1.42007
# constraint violated, safe traj, index : 781, stage: 37, value = 1.6252
# constraint violated, safe traj, index : 781, stage: 38, value = 1.88181
# constraint violated, safe traj, index : 781, stage: 39, value = 2.10964
# index : 781, time: 0.015780888, res ineq:0.0001230258442947608, exitflag : 0
# constraint violated, safe traj, index : 782, stage: 0, value = 2.74293e-08
# constraint violated, fast traj, index : 782, stage: 1, value = 0.000323823
# constraint violated, safe traj, index : 782, stage: 1, value = 0.147809
# constraint violated, safe traj, index : 782, stage: 33, value = 0.0142439
# constraint violated, safe traj, index : 782, stage: 34, value = 0.0421979
# constraint violated, safe traj, index : 782, stage: 35, value = 0.077776
# constraint violated, safe traj, index : 782, stage: 36, value = 0.123001
# constraint violated, safe traj, index : 782, stage: 37, value = 0.174041
# constraint violated, safe traj, index : 782, stage: 38, value = 0.243695
# constraint violated, safe traj, index : 782, stage: 39, value = 0.0974664
# index : 782, time: 0.01625769, res ineq:0.0003230144728581935, exitflag : 0
# constraint violated, safe traj, index : 783, stage: 0, value = 1.45821e-08
# constraint violated, fast traj, index : 783, stage: 1, value = 0.00034102
# constraint violated, safe traj, index : 783, stage: 1, value = 0.148735
# constraint violated, safe traj, index : 783, stage: 34, value = 0.00822316
# constraint violated, safe traj, index : 783, stage: 35, value = 0.0264322
# constraint violated, safe traj, index : 783, stage: 36, value = 0.0423207
# constraint violated, safe traj, index : 783, stage: 37, value = 0.056377
# constraint violated, safe traj, index : 783, stage: 38, value = 0.0689727
# constraint violated, safe traj, index : 783, stage: 39, value = 0.0773937
# index : 783, time: 0.015470311, res ineq:0.00031792105234118573, exitflag : 0
# constraint violated, fast traj, index : 784, stage: 1, value = 0.00139715
# constraint violated, safe traj, index : 784, stage: 1, value = 0.14979
# constraint violated, safe traj, index : 784, stage: 29, value = 0.000377494
# constraint violated, safe traj, index : 784, stage: 39, value = 0.00438705
# index : 784, time: 0.016521149, res ineq:6.681398648045872e-05, exitflag : 0
# constraint violated, safe traj, index : 785, stage: 0, value = 5.99411e-09
# constraint violated, fast traj, index : 785, stage: 1, value = 0.00285626
# constraint violated, safe traj, index : 785, stage: 1, value = 0.152373
# constraint violated, safe traj, index : 785, stage: 36, value = 0.00370265
# constraint violated, safe traj, index : 785, stage: 37, value = 0.00728746
# constraint violated, safe traj, index : 785, stage: 38, value = 0.00778582
# constraint violated, safe traj, index : 785, stage: 39, value = 0.00722263
# index : 785, time: 0.015284486, res ineq:0.00017333248259257875, exitflag : 0
# constraint violated, safe traj, index : 786, stage: 0, value = 7.60481e-07
# constraint violated, fast traj, index : 786, stage: 1, value = 0.00546515
# constraint violated, safe traj, index : 786, stage: 1, value = 0.154939
# index : 786, time: 0.015771327, res ineq:0.0003795856901007075, exitflag : 0
# constraint violated, fast traj, index : 787, stage: 1, value = 0.00845377
# constraint violated, safe traj, index : 787, stage: 1, value = 0.158859
# index : 787, time: 0.016520667, res ineq:0.00024153792120244072, exitflag : 0
# constraint violated, safe traj, index : 788, stage: 0, value = 5.67337e-09
# constraint violated, fast traj, index : 788, stage: 1, value = 0.0121231
# constraint violated, safe traj, index : 788, stage: 1, value = 0.16336
# constraint violated, safe traj, index : 788, stage: 38, value = 0.000904072
# constraint violated, safe traj, index : 788, stage: 39, value = 0.00188749
# index : 788, time: 0.015211287, res ineq:0.00043160691221172387, exitflag : 0
# constraint violated, fast traj, index : 789, stage: 1, value = 0.0163718
# constraint violated, safe traj, index : 789, stage: 1, value = 0.168267
# constraint violated, safe traj, index : 789, stage: 37, value = 0.00544314
# constraint violated, safe traj, index : 789, stage: 38, value = 0.0083624
# index : 789, time: 0.015500174, res ineq:7.167495090273229e-05, exitflag : 0
# constraint violated, fast traj, index : 790, stage: 0, value = 2.23165e-09
# constraint violated, fast traj, index : 790, stage: 1, value = 0.0206477
# constraint violated, safe traj, index : 790, stage: 1, value = 0.173949
# index : 790, time: 0.016467868, res ineq:7.2038856802778e-05, exitflag : 0
# constraint violated, fast traj, index : 791, stage: 1, value = 0.0248023
# constraint violated, safe traj, index : 791, stage: 1, value = 0.17936
# constraint violated, safe traj, index : 791, stage: 35, value = 0.00137
# index : 791, time: 0.015087764, res ineq:0.0001199385712749839, exitflag : 0
# constraint violated, fast traj, index : 792, stage: 0, value = 3.63633e-07
# constraint violated, safe traj, index : 792, stage: 0, value = 1.91886e-08
# constraint violated, fast traj, index : 792, stage: 1, value = 0.0284259
# constraint violated, safe traj, index : 792, stage: 1, value = 0.183828
# index : 792, time: 0.017740968, res ineq:4.0023593751638276e-05, exitflag : 0
# constraint violated, fast traj, index : 793, stage: 0, value = 1.39236e-07
# constraint violated, fast traj, index : 793, stage: 1, value = 0.0309424
# constraint violated, safe traj, index : 793, stage: 1, value = 0.187285
# index : 793, time: 0.018950138, res ineq:0.00013598957949006313, exitflag : 0
# constraint violated, fast traj, index : 794, stage: 0, value = 1.82764e-06
# constraint violated, safe traj, index : 794, stage: 0, value = 3.00969e-07
# constraint violated, fast traj, index : 794, stage: 1, value = 0.0323186
# constraint violated, safe traj, index : 794, stage: 1, value = 0.189487
# constraint violated, safe traj, index : 794, stage: 33, value = 0.000451308
# index : 794, time: 0.016583738, res ineq:0.00036047823618343133, exitflag : 0
# constraint violated, fast traj, index : 795, stage: 0, value = 1.72701e-06
# constraint violated, safe traj, index : 795, stage: 0, value = 6.05576e-07
# constraint violated, fast traj, index : 795, stage: 1, value = 0.032705
# constraint violated, safe traj, index : 795, stage: 1, value = 0.190716
# index : 795, time: 0.016466488, res ineq:0.00029115975773297276, exitflag : 0
# constraint violated, fast traj, index : 796, stage: 0, value = 5.26614e-08
# constraint violated, fast traj, index : 796, stage: 1, value = 0.0314731
# constraint violated, safe traj, index : 796, stage: 1, value = 0.193657
# constraint violated, safe traj, index : 796, stage: 39, value = 0.0136492
# index : 796, time: 0.023331128, res ineq:0.00020057582415466263, exitflag : 0
# constraint violated, fast traj, index : 797, stage: 1, value = 0.0310413
# constraint violated, safe traj, index : 797, stage: 1, value = 0.196886
# constraint violated, safe traj, index : 797, stage: 33, value = 9.88339e-05
# constraint violated, safe traj, index : 797, stage: 34, value = 6.56911e-05
# constraint violated, safe traj, index : 797, stage: 39, value = 0.0252216
# index : 797, time: 0.027723803, res ineq:7.989716287740145e-05, exitflag : 0
# constraint violated, fast traj, index : 798, stage: 0, value = 0.000831605
# constraint violated, safe traj, index : 798, stage: 0, value = 0.00219101
# constraint violated, fast traj, index : 798, stage: 1, value = 0.0320979
# constraint violated, safe traj, index : 798, stage: 1, value = 0.195988
# constraint violated, safe traj, index : 798, stage: 38, value = 0.0135593
# constraint violated, safe traj, index : 798, stage: 39, value = 0.0407204
# index : 798, time: 0.016179013, res ineq:0.00045467304217175486, exitflag : 0
# constraint violated, fast traj, index : 799, stage: 0, value = 0.0334548
# constraint violated, safe traj, index : 799, stage: 0, value = 0.197951
# constraint violated, fast traj, index : 799, stage: 39, value = 0.00485382
# constraint violated, safe traj, index : 799, stage: 39, value = 0.0109937
# index : 799, time: 0.015270981, res ineq:0.00019628838855095115, exitflag : 0
